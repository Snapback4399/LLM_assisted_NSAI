# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.97.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.97.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
import os
import json
import numpy as np
import getpass
from openai import OpenAI
from sklearn.metrics.pairwise import cosine_similarity

api_key = getpass.getpass("🔐 Enter your OpenAI API key: ")
client = OpenAI(api_key=api_key)

json_folder = '/content/drive/MyDrive/final_json'
csv_folder = '/content/drive/MyDrive/Geochem_Split_3'
output_folder = '/content/drive/MyDrive/Geochem_Knowledge'
os.makedirs(output_folder, exist_ok=True)

def load_json_text(filepath):
    with open(filepath, 'r') as f:
        data = json.load(f)
    text = f"{data.get('Model_Name', '')}\n" + "\n".join(f"{k}: {v}" for k, v in data.items() if k != "ai_modification_log")
    return text, data

def get_embedding(text, model="text-embedding-3-small"):
    text = text.replace("\n", " ")
    response = client.embeddings.create(
        input=[text],
        model=model
    )
    return response.data[0].embedding

def query_chatgpt(deposit_type, json_knowledge):
    prompt = f"""
You are a geologist AI assistant. The following is a JSON object describing a mineral deposit model:

{json.dumps(json_knowledge, indent=2)}

Based on this description, extract and summarize knowledge relevant to the following deposit type:
"{deposit_type}"

Respond with only relevant information that matches this deposit type, in JSON format.
"""
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.2
    )
    return response.choices[0].message.content

json_embeddings = []
json_data_list = []

print("📦 Generating embeddings for JSON models...")
for file in os.listdir(json_folder):
    if file.endswith(".json"):
        file_path = os.path.join(json_folder, file)
        text, data = load_json_text(file_path)
        embedding = get_embedding(text)
        json_embeddings.append(embedding)
        json_data_list.append((file, data))

print("\n🔍 Matching CSV deposit types to JSON models...")
for csv_file in os.listdir(csv_folder):
    if not csv_file.endswith(".csv"):
        continue

    deposit_type = csv_file.replace("Saved", "").replace(".csv", "").strip()
    print(f"\n🔎 Processing: {deposit_type}")

    try:
        deposit_embedding = get_embedding(deposit_type)
        sims = cosine_similarity([deposit_embedding], json_embeddings)[0]
        best_idx = int(np.argmax(sims))
        best_model_name, best_model_data = json_data_list[best_idx]

        print(f"✅ Best matched model: {best_model_name} (similarity={sims[best_idx]:.3f})")

        matched_knowledge = query_chatgpt(deposit_type, best_model_data)

        output_path = os.path.join(output_folder, f"{csv_file.replace('.csv', '_knowledge.json')}")
        with open(output_path, 'w') as f:
            f.write(matched_knowledge)
        print(f"📁 Saved: {output_path}")

    except Exception as e:
        print(f"❌ Error with {csv_file}: {e}")
# Out:
# 🔐 Enter your OpenAI API key: ··········
# 📦 Generating embeddings for JSON models...
#
# 🔍 Matching CSV deposit types to JSON models...
#
# 🔎 Processing: Au
# ✅ Best matched model: Descriptive model of carbonate-hosted Au-Ag_ocr_output_final.json (similarity=0.330)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Au_knowledge.json
#
# 🔎 Processing: Black shale
# ✅ Best matched model: Descriptive model of emerald veins_ocr_output_final.json (similarity=0.443)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Black shale_knowledge.json
#
# 🔎 Processing: Breccia pipe U
# ✅ Best matched model: Descriptive model of diamond pipes_ocr_output_final.json (similarity=0.463)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Breccia pipe U_knowledge.json
#
# 🔎 Processing: Carbonatite
# ✅ Best matched model: Descriptbe model of carbonatite deposits_ocr_output_final.json (similarity=0.605)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Carbonatite_knowledge.json
#
# 🔎 Processing: Cu
# ✅ Best matched model: Descriptive model of basaltic Cu_ocr_output_final.json (similarity=0.344)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Cu_knowledge.json
#
# 🔎 Processing: Distal Disseminated Ag-Au
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.507)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Distal Disseminated Ag-Au_knowledge.json
#
# 🔎 Processing: Distal disseminated Ag-Au
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.530)
# ❌ Error with Distal disseminated Ag-Au.csv: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
#
# 🔎 Processing: Fluorspar
# ✅ Best matched model: Descriptive model of porphyry Mo, low-F_ocr_output_final.json (similarity=0.418)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Fluorspar_knowledge.json
#
# 🔎 Processing: High sulfidation Au-Ag
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.671)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/High sulfidation Au-Ag_knowledge.json
#
# 🔎 Processing: High sulfidation Au-Ag (Cu)
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.649)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/High sulfidation Au-Ag (Cu)_knowledge.json
#
# 🔎 Processing: High sulfidation Sulfur
# ✅ Best matched model: Descriptive model of hot-spring Hg_ocr_output_final.json (similarity=0.523)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/High sulfidation Sulfur_knowledge.json
#
# 🔎 Processing: IOA
# ✅ Best matched model: Descriptive model of volcanogenic Mn_ocr_output_final.json (similarity=0.207)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/IOA_knowledge.json
#
# 🔎 Processing: IOCG
# ✅ Best matched model: Descriptive model of pediform chromite_ocr_output_final.json (similarity=0.355)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/IOCG_knowledge.json
#
# 🔎 Processing: IOCG, Blackbird type
# ✅ Best matched model: Descriptive model of Blackbird Co-Cu_ocr_output_final.json (similarity=0.440)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/IOCG, Blackbird type_knowledge.json
#
# 🔎 Processing: Intermediate sulfidation Sb, jasperoid
# ✅ Best matched model: Descriptive model of volcanic-hosted Cu-As-Sb_ocr_output_final.json (similarity=0.562)
# ❌ Error with Intermediate sulfidation Sb, jasperoid.csv: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
#
# 🔎 Processing: Intermediate sulfidation epithermal Au-Ag
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.680)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Intermediate sulfidation epithermal Au-Ag_knowledge.json
#
# 🔎 Processing: Li-Clay
# ✅ Best matched model: Descriptive model of shoreline placer Ti_ocr_output_final.json (similarity=0.343)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Li-Clay_knowledge.json
#
# 🔎 Processing: Li-clay
# ✅ Best matched model: Descriptive model of warm-current type phosphate deposits_ocr_output_final.json (similarity=0.304)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Li-clay_knowledge.json
#
# 🔎 Processing: Lithocap alunite
# ✅ Best matched model: Descriptive model of epithermal quartz-alunite Au_ocr_output_final.json (similarity=0.500)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Lithocap alunite_knowledge.json
#
# 🔎 Processing: Lithocap alunite_High sulfidation Au-Ag
# ✅ Best matched model: Descriptive model of epithermal quartz-alunite Au_ocr_output_final.json (similarity=0.628)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Lithocap alunite_High sulfidation Au-Ag_knowledge.json
#
# 🔎 Processing: Lithocap kaolinite_High sulfidation Au-Ag
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.633)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Lithocap kaolinite_High sulfidation Au-Ag_knowledge.json
#
# 🔎 Processing: Low sulfidation
# ✅ Best matched model: Descriptive model of sedimentary exhalative Zn-Pb_ocr_output_final.json (similarity=0.495)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Low sulfidation_knowledge.json
#
# 🔎 Processing: Low sulfidation Au
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.620)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Low sulfidation Au_knowledge.json
#
# 🔎 Processing: Low sulfidation Au-Ag
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.672)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Low sulfidation Au-Ag_knowledge.json
#
# 🔎 Processing: Low sulfidation Hg
# ✅ Best matched model: Descriptive model of hot-spring Hg_ocr_output_final.json (similarity=0.570)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Low sulfidation Hg_knowledge.json
#
# 🔎 Processing: Low sulfidation Sb
# ✅ Best matched model: Descriptive model of volcanic-hosted Cu-As-Sb_ocr_output_final.json (similarity=0.554)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Low sulfidation Sb_knowledge.json
#
# 🔎 Processing: Low sulfidation epithermal Au-Ag
# ✅ Best matched model: Descriptive model of hot-spring Au-Ag_ocr_output_final.json (similarity=0.704)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Low sulfidation epithermal Au-Ag_knowledge.json
#
# 🔎 Processing: Peralkaline syenite_granite_rhyolite_alaskite_pegmatites
# ✅ Best matched model: Descriptive model of Alaskan PGE_ocr_output_final.json (similarity=0.564)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Peralkaline syenite_granite_rhyolite_alaskite_pegmatites_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide
# ✅ Best matched model: Descriptive model of Sn-polymetallic veins_ocr_output_final.json (similarity=0.571)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide IS
# ✅ Best matched model: Descriptive model of Sn-polymetallic veins_ocr_output_final.json (similarity=0.584)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide IS_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide S-R-V-IS
# ✅ Best matched model: Descriptive model of Sn-polymetallic veins_ocr_output_final.json (similarity=0.569)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide S-R-V-IS_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide intermediate sulfidation
# ✅ Best matched model: Descriptive model of Duluth Cu-Ni-PGE_ocr_output_final.json (similarity=0.512)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide intermediate sulfidation_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide replacement
# ✅ Best matched model: Descriptive model of replacement Mn_ocr_output_final.json (similarity=0.561)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide replacement_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide skarn
# ✅ Best matched model: Descriptive model of Zn-Pb skarn deposits_ocr_output_final.json (similarity=0.674)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide skarn_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide skarn_replacement
# ✅ Best matched model: Descriptive model of replacement Sn_ocr_output_final.json (similarity=0.630)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide skarn_replacement_knowledge.json
#
# 🔎 Processing: Polymetallic sulfide vein
# ✅ Best matched model: Descriptive model of Sn-polymetallic veins_ocr_output_final.json (similarity=0.704)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Polymetallic sulfide vein_knowledge.json
#
# 🔎 Processing: Porphyry Cu
# ✅ Best matched model: Descriptive model of porphyry Cu_ocr_output_final.json (similarity=0.664)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Porphyry Cu_knowledge.json
#
# 🔎 Processing: Porphyry Cu (Au)
# ✅ Best matched model: Descriptive model of porphyry Cu-Au_ocr_output_final.json (similarity=0.631)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Porphyry Cu (Au)_knowledge.json
#
# 🔎 Processing: Porphyry Cu or High sulfidation Au-Ag
# ✅ Best matched model: Descriptive model of porphyry Cu-Au_ocr_output_final.json (similarity=0.665)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Porphyry Cu or High sulfidation Au-Ag_knowledge.json
#
# 🔎 Processing: Porphyry Cu-Mo
# ✅ Best matched model: Descriptive model of porphyry Cu-Mo_ocr_output_final.json (similarity=0.713)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Porphyry Cu-Mo_knowledge.json
#
# 🔎 Processing: Porphyry Mo
# ✅ Best matched model: Descriptive model of porphyry Mo, low-F_ocr_output_final.json (similarity=0.579)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Porphyry Mo_knowledge.json
#
# 🔎 Processing: Porphyry_skarn Cu
# ✅ Best matched model: Descriptive model of porphyry Cu, skarn-related deposits_ocr_output_final.json (similarity=0.669)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Porphyry_skarn Cu_knowledge.json
#
# 🔎 Processing: Porphyry_skarn Cu and Distal disseminated Au-Au
# ✅ Best matched model: Descriptive model of porphyry Cu-Au_ocr_output_final.json (similarity=0.643)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Porphyry_skarn Cu and Distal disseminated Au-Au_knowledge.json
#
# 🔎 Processing: REE rich rhyolite
# ✅ Best matched model: Descriptive model of rhyolite-hosted Sn_ocr_output_final.json (similarity=0.485)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/REE rich rhyolite_knowledge.json
#
# 🔎 Processing: Replacement Mn
# ✅ Best matched model: Descriptive model of replacement Mn_ocr_output_final.json (similarity=0.556)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Replacement Mn_knowledge.json
#
# 🔎 Processing: Skarn W
# ✅ Best matched model: Descriptive model of W skarn deposits_ocr_output_final.json (similarity=0.570)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Skarn W_knowledge.json
#
# 🔎 Processing: Volcanogenic Be
# ✅ Best matched model: Descriptive model of volcanogenic U_ocr_output_final.json (similarity=0.424)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Volcanogenic Be_knowledge.json
#
# 🔎 Processing: Volcanogenic U
# ✅ Best matched model: Descriptive model of volcanogenic U_ocr_output_final.json (similarity=0.557)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/Volcanogenic U_knowledge.json
#
# 🔎 Processing: unknown
# ✅ Best matched model: Descriptive model of volcanogenic U_ocr_output_final.json (similarity=0.251)
# 📁 Saved: /content/drive/MyDrive/Geochem_Knowledge/unknown_knowledge.json
